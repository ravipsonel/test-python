# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Aug 21 14:42:02 2024

@author: Jeyak
"""
import numpy as np
import pandas as pd
import datetime as dt
# from math import abs
from adtk.detector import ThresholdAD
from fastapi.responses import JSONResponse
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import TimeSeriesSplit, train_test_split

# import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv1D, MaxPooling1D, TimeDistributed, Flatten, GRU, Dense

from app import db
from app.config import ModelConfig
from app.helper import load_model, save_model, get_var_name


models = {}
now = dt.datetime.now()

disposition_filepath = './data/ML_Training_Data.csv'
disposition_dataset = pd.read_csv(disposition_filepath)
# Rename all "Column" name to lowercase.
disposition_dataset.columns = map(str.lower, disposition_dataset.columns)

# ---
# anomaly_filepath = './data/cloudutilization_13082024.csv'
# anomaly_dataset = pd.read_csv(anomaly_filepath)
# anomaly_dataset.set_index('usagedate', drop=True, inplace=True)
# anomaly_dataset['servicename_id'] = anomaly_dataset['servicename'].apply(lambda x: get_var_name(x))

# ---
seasonal_data = pd.read_csv(r'./data/seasonal_data.csv')
months = ('jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec')

def update_current_time():
    global now
    now = dt.datetime.now()
    return now

def fn(x):
    x = x.lower().split('-')
    return now.year, months.index(x[0])+1, int(x[1])

seasonal_data['StartDate'] = seasonal_data['StartDate'].apply(lambda x: dt.datetime(*fn(x)))
seasonal_data['EndDate'] = seasonal_data['EndDate'].apply(lambda x: dt.datetime(*fn(x)))
seasonal_data['MinThresholdValue'] = seasonal_data['MinThresholdValue'].astype(np.float64)
seasonal_data['MaxThresholdValue'] = seasonal_data['MaxThresholdValue'].astype(np.float64)


# Define window size
window_size = ModelConfig.WINDOW_SIZE


def predict_disposition(model, label_encoders, df):
    # Label Encoding
    for column in df.columns:
        df[column] = LabelEncoder().fit_transform(df[column])

    # Predict
    y_pred = model.predict(df)
    df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
    return df


def get_model_id(model_name, service_name=None):
    model_name = get_var_name(model_name)
    if service_name is None:
        return model_name
    return f'{model_name}_{get_var_name(service_name)}' 

def make_Xy(data, n_input, n_out) :
    data = data.values
    X, y = list(), list()
    in_start = 0
    for _ in range(len(data)):
        in_end = in_start + n_input
        out_end = in_end + n_out
        if out_end <= len(data):
            x_input = data[in_start:in_end, : ]
            x_input = x_input.reshape((len(x_input), -1))
            X.append(x_input)
            y.append(data[in_end:out_end, : ])
        in_start += 1
    X = np.array(X)
    y = np.array(y)[ : , : , -1:]
    return X, y

def min_max_scale(data, scalers={}, inv=False):
    if(len(scalers)==0) :
        for i in range(data.shape[2]):
            scalers[i] = MinMaxScaler(feature_range=(0, 1))
            scalers[i].fit_transform(data[:, :, i])
            data[:, :, i] = scalers[i].transform(data[:, :, i])
        return data, scalers
    else :
        for i in range(data.shape[2]):
            if inv :
                data[:, :, i] = scalers[i].inverse_transform(data[:, :, i])
            else :
                data[:, :, i] = scalers[i].transform(data[:, :, i])
        return data
    
def get_service_list():
    query = 'SELECT DISTINCT servicename FROM cloudutilization';
    return {get_var_name(row[0]): row[0].strip() for row in db.sql(query)}

def get_service_row(service):
    query = 'SELECT servicename FROM cloudutilization';
    return {get_var_name(row[0]): row[0].strip() for row in db.sql(query)}
    
    
def get_saved_model(model_id):
    if models.get(model_id) is None:
        # Load the model
        models[model_id] = load_model(model_id=model_id)
    
    # Pickle
    return models[model_id]


def get_anomalies(new_pred_plot, prediction_df):
    low = new_pred_plot['last_original_days_value'].min()
    high = new_pred_plot['last_original_days_value'].max()
    threshold_detector = ThresholdAD(low=low, high=high)
    anomalies = threshold_detector.detect(prediction_df['next_predicted_days_value'])  
    return anomalies


def get_latest_season_data(seasonal_data, within_days=1):
    # today = dt.date.today()
    today = dt.datetime.now()
    tomorrow = (today + dt.timedelta(days=within_days))
    latest_seasonal_data = seasonal_data.loc[
        (seasonal_data['StartDate'] >= now) & (seasonal_data['EndDate'] <= tomorrow)
    ]
    print(f'Date Range: {today} - {tomorrow}')
    return latest_seasonal_data
# Out:
# Connecting to the database...
# Connection String:  postgresql://postgres:postgres%40123@localhost:5432/ApplicationInsights
# Connected. <cursor object at 0x0000026F86E98660; closed: 0>

# %%
# Cost Anamoly Detection 
model_name = 'anomalies'
service_name = None


service_list = {}
if service_name is None:
    # Predict for all the services one by one.
    service_list = get_service_list()
else:
    # Predict for particular service.
    service_list[get_var_name(service_name)] = service_name
    
for service_id, service_name in service_list.items():
    if '-' in service_name and len(service_name) == 36:
        # SKip "UUIDs"
        print(f"Warn: Skipping UUID <{service_name}>...")
        continue
    
    # Train the model for particular service.
    model_id = get_model_id(model_name, service_name)
    try:
        pkl = get_saved_model(model_id) 
    except Exception as e:
        print(f'Model file not found. It might not be trained due to an insufficient data. Msg: {str(e)}')
        continue
    
    for anomaly_dataset in db.df_fetch_data(
        tbl_name='cloudutilization', 
        where={'servicename': service_name}
    ):
        # print(anomaly_dataset)
        anomaly_dataset.set_index('usagedate', drop=True, inplace=True)
        anomaly_dataset['servicename_id'] = anomaly_dataset['servicename'].apply(lambda x: get_var_name(x))

        
        filter_columns = ['cloudprovidername', 'cloudtype']
        filter_df = anomaly_dataset[filter_columns]
        filter_df['pretaxcost'] = anomaly_dataset['pretaxcost']
        # Remove all None rows
        for clm in filter_columns:
            filter_df[clm] = filter_df[clm].fillna('(none)')
        
        for grp_name, df in filter_df.groupby(filter_columns):
            print(grp_name, df)

            data = df[['pretaxcost']]#.values.reshape(-1, 1)
            
            try:
                data_test = data[15:]
                X_test , y_test = make_Xy(data_test,15,1) 
            except IndexError:
                print(f'Warn: Unable to predict <{service_name} - {grp_name}> due to insufficient data.')
                continue
            (X_test_sc, scale_X_test) = min_max_scale(X_test.copy(), {})
            (y_test_sc, scale_y_test) = min_max_scale(y_test.copy(), {})
            
            lst_output = pkl['model'].predict(X_test_sc)
            # cb_output = scale_y_test[0].inverse_transform(cb_model.predict(X_test_sc)).reshape(-1)
    
            # Normalize the data
            scaler = MinMaxScaler(feature_range=(0, 1))
            data_normalized = scaler.fit_transform(data)
            closedf =  data_normalized.copy()
            
            training_size=int(len(closedf)*0.60)
            test_size=len(closedf)-training_size
            train_data,test_data= closedf[0:training_size,:], closedf[training_size:len(closedf),:1]
            # print("train_data: ", train_data.shape)
            # print("test_data: ", test_data.shape)
            
            
            time_step = 30
            x_input=test_data[len(test_data)-(time_step):].reshape(1,-1)
            temp_input=list(x_input)
            temp_input=temp_input[0].tolist()
            
            lst_output=[]
            n_steps=time_step
            i=0
            pred_days = 14
            
            try:
                while(i<pred_days):
                    if(len(temp_input)>time_step):
                        x_input=np.array(temp_input[1:])
                        #print("{} day input {}".format(i,x_input))
                        x_input = x_input.reshape(1,-1)
                        x_input = x_input.reshape((1, n_steps, 1))
                        
                        yhat = pkl['model'].predict(x_input, verbose=0)
                        #print("{} day output {}".format(i,yhat))
                        temp_input.extend(yhat[0].tolist())
                        temp_input=temp_input[1:]
                        #print(temp_input)
                       
                        lst_output.extend(yhat.tolist())
                        i=i+1
                        
                    else:
                        
                        x_input = x_input.reshape((1, n_steps,1))
                        yhat = pkl['model'].predict(x_input, verbose=0)
                        temp_input.extend(yhat[0].tolist())
                        
                        lst_output.extend(yhat.tolist())
                        i=i+1
            except ValueError:
                print(f'Warn: Unable to predict <{service_name} - {grp_name}> due to insufficient data.')
                continue
                           
            print("Output of predicted next days: ", len(lst_output))
            last_days=np.arange(1,time_step+1)
            day_pred=np.arange(time_step+1,time_step+pred_days+1)
            # print(last_days)
            # print(day_pred)
            
            temp_mat = np.empty((len(last_days)+pred_days+1,1))
            temp_mat[:] = np.nan
            temp_mat = temp_mat.reshape(1,-1).tolist()[0]
            
            last_original_days_value = temp_mat
            next_predicted_days_value = temp_mat
            
            last_original_days_value[0:time_step+1] = scaler.inverse_transform(closedf[len(closedf)-time_step:]).reshape(1,-1).tolist()[0]
            next_predicted_days_value[time_step:] = scaler.inverse_transform(np.array(lst_output).reshape(-1,1)).reshape(1,-1).tolist()[0]
            
            new_pred_plot = pd.DataFrame({
                'last_original_days_value':last_original_days_value,
                'next_predicted_days_value':next_predicted_days_value
            })
            pred_start_datetime = dt.datetime.now()
            pred_end_datetime = pred_start_datetime+dt.timedelta(pred_days)
            date_df = pd.date_range(start=pred_start_datetime-dt.timedelta(time_step-1), end=pred_end_datetime, freq='D')
            # date_df = pd.date_range(start=, end=pred_end_datetime, freq='D')
            
            # print(new_pred_plot.index)
            # print(len(date_df))
            
            new_pred_plot.index = date_df
            history = new_pred_plot.iloc[:time_step+1]
            prediction_df = new_pred_plot.iloc[time_step:]

            # Find the anomalies.
            anomaly_df = get_anomalies(new_pred_plot, prediction_df)
            detected_anamolies = anomaly_df.loc[anomaly_df == True]
            # print(prediction_df)
            # print(anomaly_df)

            # Set the 'usage_date'
            prediction_df.index.name = 'usage_date'
            prediction_df.reset_index(inplace=True)
            prediction_df['usage_date'] = prediction_df['usage_date'].dt.date

            # set other relevant columns
            prediction_df['service_name'] = service_name
            prediction_df['created_on'] = now
            prediction_df['created_by'] = 'CRON/API'
            for i, clm in enumerate(filter_columns):
                prediction_df[clm] = None if grp_name[i] == '(none)' else grp_name[i].strip()

            prediction_df.drop('last_original_days_value', axis=1, inplace=True)
            prediction_df.rename(columns={
                'cloudprovidername': 'cloud_provider_name',
                'cloudtype': 'cloud_type',
                'next_predicted_days_value': 'predicted_cost'
            }, inplace=True)
    
            # Save the prediction data into the database.
            db.insert_or_update(tbl_name='alert_anomalies', df=prediction_df, on_columns=['service_name', 'usage_date'])
            
            # Save the anomalies to the database.
            #! db.insert_or_update(tbl_name='cloudalertmessagesdetails', df=anomaly_df, on_columns=['usage_date'])
        
        if len(service_list) > 1:
            results = service_list
        else:
            results = prediction_df.to_json(orient='records')
print(results)
# Out:
# Executing "SELECT DISTINCT servicename FROM cloudutilization"...
# Warn: Skipping UUID <f1c63817-e85f-b2f5-cbc8-f8d0f945c9d5>...
# Warn: Skipping UUID <e30cc83a-fcb9-a82a-a37b-9af0ed4d68cf>...
# Warn: Skipping UUID <a37735ab-7617-b5b3-a059-ca9120e18aee>...
# Warn: Skipping UUID <44014c47-2a09-0409-a599-c8cbe974b101>...
# Warn: Skipping UUID <e5ad3226-7932-6dc5-350b-22b64783debe>...
# Warn: Skipping UUID <0b6a1ef1-be0a-de7d-7931-0acf8a18e357>...
# Warn: Skipping UUID <b7bf570d-5315-1710-00b8-f865a5a1c884>...
# Warn: Skipping UUID <ad9fa701-87bc-a99d-7b79-be1ba511b20a>...
# Warn: Skipping UUID <c65b9ac8-36b4-d31d-89a7-f0a3b37179d0>...
# Warn: Skipping UUID <c77272b9-ac5e-9747-9837-baad37472dd0>...
# Warn: Skipping UUID <77462005-91da-72b1-c738-6bc5a3c8110d>...
# Warn: Skipping UUID <4d1328d2-deeb-2036-3813-bcbeee76a898>...
# Loading <./pkl/anomalies_amazon_relational_database_service.pkl>...
# Executing SELECT * FROM cloudutilization WHERE servicename = 'Amazon Relational Database Service'...
# ('(none)', 'AWS                                               ')                     cloudprovidername  \
# usagedate
# 2024-07-20 06:21:00            (none)
# 2024-07-27 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
#
#                                                              cloudtype  \
# usagedate
# 2024-07-20 06:21:00  AWS                                           ...
# 2024-07-27 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
#
#                      pretaxcost
# usagedate
# 2024-07-20 06:21:00      153.27
# 2024-07-27 06:21:00        2.44
# 2024-07-29 06:21:00        2.35
# 2024-07-29 06:21:00       30.64
# 2024-07-29 06:21:00      113.76
# 2024-07-29 06:21:00      126.05
# 2024-07-29 06:21:00       79.18
# 2024-07-29 06:21:00       13.92
# 2024-07-29 06:21:00        0.22
# 2024-07-29 06:21:00       13.44
# 2024-07-29 06:21:00       79.18
# 2024-07-29 06:21:00       13.46
# 2024-07-29 06:21:00        0.11
# 2024-07-29 06:21:00       13.46
# 2024-07-29 06:21:00       77.54
# 2024-07-29 06:21:00       23.78
# 2024-07-29 06:21:00      387.78
# 2024-07-29 06:21:00        0.11
# 2024-07-29 06:21:00        2.44
# 2024-07-29 06:21:00       48.78
# 2024-07-29 06:21:00       27.73
# 2024-07-29 06:21:00        0.24
# Warn: Unable to predict <Amazon Relational Database Service - ('(none)', 'AWS                                               ')> due to insufficient data.
# Warn: Skipping UUID <7ed571ef-bc05-9755-1eb9-3e66441affe7>...
# Warn: Skipping UUID <85b5f5a3-a813-587b-0d3f-4fbe0582d7c2>...
# Warn: Skipping UUID <3eb7cc19-d59b-2fdc-8584-fbb2e911c971>...
# Warn: Skipping UUID <824889ab-7a43-9e57-c61c-f109d0309d1c>...
# Warn: Skipping UUID <15349fbe-c675-fe7e-bde3-2f93857ebf8c>...
# Warn: Skipping UUID <800c1c28-1163-fee7-732a-24851b0160d8>...
# Warn: Skipping UUID <b03b63fa-bb55-64fe-222d-89a1693a3833>...
# Loading <./pkl/anomalies_amazon_documentdb_with_mongodb_compatibility.pkl>...
# Model file not found. It might not be trained due to an insufficient data. Msg: [Errno 2] No such file or directory: './pkl/anomalies_amazon_documentdb_with_mongodb_compatibility.pkl'
# Warn: Skipping UUID <317980af-9d0e-64f3-18cb-93098e796e9f>...
# Warn: Skipping UUID <dc0b6b13-cdd1-0b9b-ac1d-442d6e817142>...
# Warn: Skipping UUID <62b8ab6e-3f23-72c1-2158-14a0432c2157>...
# Warn: Skipping UUID <bd09a9d3-c4fb-ac86-f510-e2e05339438e>...
# Warn: Skipping UUID <4d2be448-363f-f3d6-b331-08fa064f58b5>...
# Warn: Skipping UUID <722032fd-6835-192d-08d1-4b0db147a96d>...
# Warn: Skipping UUID <e964cb36-eb59-fe0a-f5bd-2a33b865c8c0>...
# Warn: Skipping UUID <2750ac74-acdf-98e9-b7b5-0a566696eea1>...
# Warn: Skipping UUID <ca237f8c-6e81-f4c4-3c90-ec6e7829702f>...
# Warn: Skipping UUID <da31f0e7-84c5-4541-90a9-c629a3add2cf>...
# Warn: Skipping UUID <685aca53-8c80-da10-19c1-96f2424d2701>...
# Warn: Skipping UUID <3c70b164-23b8-2fe3-8b35-6a99a860a18f>...
# Warn: Skipping UUID <f514ebbf-5650-2b3c-1953-10e552c1aa1f>...
# Warn: Skipping UUID <28eae68b-97d7-0c93-220b-c5168e2b3e9c>...
# Warn: Skipping UUID <2f34f00f-14d8-b8e4-2d1f-54151afc9494>...
# Warn: Skipping UUID <19232b68-3a25-ba8c-f22e-85ead0ec40aa>...
# Warn: Skipping UUID <96cdad78-0ffc-3068-96d2-de9f6d03ac0b>...
# Warn: Skipping UUID <2e527682-1992-8844-2c52-2f39f9eaca7c>...
# Loading <./pkl/anomalies_aws_secrets_manager.pkl>...
# Model file not found. It might not be trained due to an insufficient data. Msg: [Errno 2] No such file or directory: './pkl/anomalies_aws_secrets_manager.pkl'
# Warn: Skipping UUID <c8d49275-8513-b537-95ef-228de5c00532>...
# Warn: Skipping UUID <08145968-48f8-0d2b-8855-3ad563dac911>...
# Warn: Skipping UUID <352b9b4a-7c1c-d560-2637-c6d941c4308d>...
# Warn: Skipping UUID <6b62cd79-7b90-2a08-e1ce-2c1caf06946a>...
# Warn: Skipping UUID <e6822589-2fc5-90a4-09bf-c500b03ae080>...
# Warn: Skipping UUID <22c1bc4a-db7e-f0f4-7559-5766a00d57ef>...
# Warn: Skipping UUID <41eb2de0-bed7-b44e-f72b-594666b9d1ba>...
# Warn: Skipping UUID <046644dc-6da6-f4b2-e41c-db6928813df9>...
# Loading <./pkl/anomalies_log_analytics.pkl>...
# Model file not found. It might not be trained due to an insufficient data. Msg: [Errno 2] No such file or directory: './pkl/anomalies_log_analytics.pkl'
# Warn: Skipping UUID <7b945df4-bcad-03f4-214a-7877ee640804>...
# Warn: Skipping UUID <02771126-2b5f-8e77-5404-e3148c6c30d0>...
# Warn: Skipping UUID <de5f7c23-afa5-1793-7ba9-72b2601d7d20>...
# Warn: Skipping UUID <58dde662-daf7-54d9-7b30-be97ec5cc825>...
# Warn: Skipping UUID <3ae517ed-1c65-8676-b902-85e9c2cf980f>...
# Warn: Skipping UUID <c2a4a578-a035-eb73-9cfb-d68ce01eaff0>...
# Warn: Skipping UUID <dbfa1159-ccac-34bf-b93d-8476e8725734>...
# Warn: Skipping UUID <f63318c0-795b-41d5-7b94-8df45fc7eca2>...
# Warn: Skipping UUID <b4ca6b64-bbec-f348-1740-c171df1c884f>...
# Loading <./pkl/anomalies_api_management.pkl>...
# Model file not found. It might not be trained due to an insufficient data. Msg: [Errno 2] No such file or directory: './pkl/anomalies_api_management.pkl'
# Loading <./pkl/anomalies_amazon_dynamodb.pkl>...
# Model file not found. It might not be trained due to an insufficient data. Msg: [Errno 2] No such file or directory: './pkl/anomalies_amazon_dynamodb.pkl'
# Warn: Skipping UUID <4a8d5365-6195-68d8-25c9-2bb484e1024d>...
# Warn: Skipping UUID <e9086a02-9740-474d-7ea3-b660cd289881>...
# Warn: Skipping UUID <66ef1f8a-0427-d9e6-1647-3a14e3b64e55>...
# Warn: Skipping UUID <f202c52c-9943-94a8-d599-4833d033e2d2>...
# Warn: Skipping UUID <5c325b33-8f7d-54b3-97d5-79bcdfcf053f>...
# Warn: Skipping UUID <e0f4c4b5-1369-0882-d946-5e9a746fdead>...
# Warn: Skipping UUID <c4223e8a-8fc0-d801-48a3-c7f10f4577c9>...
# Warn: Skipping UUID <8c45280c-5804-5e39-5c1d-a419ad62655a>...
# Warn: Skipping UUID <c6648786-662d-a637-35da-5adf2eaebcda>...
# Warn: Skipping UUID <367950ed-1a22-8469-3e5c-45df8d9fef79>...
# Warn: Skipping UUID <6055f23f-1a3d-2c58-a39c-7864b1d8c4b8>...
# Warn: Skipping UUID <d55ed643-4cda-ba18-616f-3d34ee3ee53a>...
# Warn: Skipping UUID <946de661-f3bf-89a5-1c67-fad2770669ca>...
# Warn: Skipping UUID <644944c1-6d7f-d86a-9ce6-008c425307ef>...
# Warn: Skipping UUID <4d7e3f64-f02d-7e90-67ba-985c1986b3e3>...
# Warn: Skipping UUID <88eb271d-7a5b-5f8a-c216-6adb8dee4975>...
# Warn: Skipping UUID <58b0a748-5d49-7a35-538b-03a2dcefa824>...
# Warn: Skipping UUID <2f4dfdb3-1fbe-61ce-67d2-de24fef62948>...
# Warn: Skipping UUID <61ef9ee7-0c92-83b8-90ce-bc936fe3604b>...
# Warn: Skipping UUID <567c82e8-7c82-aacb-b028-ae963206caaf>...
# Warn: Skipping UUID <b3139718-8c76-9b22-b554-c2b24febba07>...
# Warn: Skipping UUID <7be56b21-dc99-5990-336a-6ece4bd655d4>...
# Warn: Skipping UUID <88e043b1-69fd-5b5b-8131-8a676430a517>...
# Warn: Skipping UUID <428bd9e8-c8c9-febe-97ad-5c96a64da6d4>...
# Warn: Skipping UUID <85ab3575-f449-033b-18a4-ada73eda00e1>...
# Warn: Skipping UUID <e28f9f96-b4dc-bc93-058e-35d3a9e8254f>...
# Warn: Skipping UUID <792887a2-ef8b-4f41-b09b-10c75a0ecb4a>...
# Warn: Skipping UUID <a2e98d08-2ef7-5e81-9fbd-c8d824e90951>...
# Warn: Skipping UUID <2393bd34-ffee-4f22-a925-f1bebfd67e76>...
# Warn: Skipping UUID <57cdd337-6427-01fe-0f75-f162f78f0134>...
# Warn: Skipping UUID <97ea3fee-1ec2-0b71-758d-fe9ab7c32fbc>...
# Warn: Skipping UUID <23883eb2-ec75-f264-0fe1-8762b640bf27>...
# Warn: Skipping UUID <ed2dad9c-6aef-e500-a549-6d64a068bb8e>...
# Warn: Skipping UUID <361d07e2-07e8-5e50-e51c-1abac07cdfb6>...
# Warn: Skipping UUID <75cc26b3-d8a7-7a92-4c27-f580c052c1d6>...
# Warn: Skipping UUID <c1206f45-0c85-58f3-1685-5f4b6bb10d33>...
# Loading <./pkl/anomalies_aws_cost_explorer.pkl>...
# Model file not found. It might not be trained due to an insufficient data. Msg: [Errno 2] No such file or directory: './pkl/anomalies_aws_cost_explorer.pkl'
# Warn: Skipping UUID <cd494e40-1344-cebe-ec0d-d28d28c112e3>...
# Warn: Skipping UUID <8fe3e3ee-3619-8afc-1d7b-92ec9b2a69d5>...
# Loading <./pkl/anomalies_amazoncloudwatch.pkl>...
# Executing SELECT * FROM cloudutilization WHERE servicename = 'AmazonCloudWatch'...
# ('(none)', 'AWS                                               ')                     cloudprovidername  \
# usagedate
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
#
#                                                              cloudtype  \
# usagedate
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
#
#                      pretaxcost
# usagedate
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00       10.35
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.21
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.32
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.33
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00       11.01
# Warn: Unable to predict <AmazonCloudWatch - ('(none)', 'AWS                                               ')> due to insufficient data.
# Warn: Skipping UUID <36389016-3a45-8561-b47b-5c0dbaaf4093>...
# Warn: Skipping UUID <d4037bc4-6d51-1076-1b6c-95461b9408cf>...
# Warn: Skipping UUID <98edef19-69d6-8a15-e90f-bc702af3d864>...
# Warn: Skipping UUID <19994119-b39f-c588-d89b-c52db316c746>...
# Warn: Skipping UUID <4651b824-3674-637c-9b16-be067fea567d>...
# Warn: Skipping UUID <fc670bb9-be36-c038-1621-ff2c65da01c0>...
# Warn: Skipping UUID <65f31bd7-cf02-e7c5-f9b6-47940aeb607e>...
# Warn: Skipping UUID <567ea4a0-99ed-413e-ebdf-53d6e7d5f64f>...
# Warn: Skipping UUID <4a923587-a519-3100-8d2b-ac6adf6c0b58>...
# Warn: Skipping UUID <10650dc2-09a6-90ee-1657-3a67a42d3299>...
# Warn: Skipping UUID <32b61037-5542-9738-4dbd-a7189b859f66>...
# Warn: Skipping UUID <3d2e981b-c764-4773-7045-6811f07cb594>...
# Warn: Skipping UUID <63ff2274-2e9e-59a9-70c7-152b17319841>...
# Warn: Skipping UUID <8d7c48f5-6048-ad98-91de-5c5798d605cb>...
# Warn: Skipping UUID <bd8ad9de-2482-7600-a6ba-b2b178b435f0>...
# Warn: Skipping UUID <3479ae4b-a682-f680-352a-bbc9e5d658ed>...
# Warn: Skipping UUID <87fd4535-c032-bdeb-bae9-1019fb43e2bd>...
# Warn: Skipping UUID <2dd56c8f-202b-86a1-a0ce-81dd3a6394f6>...
# Warn: Skipping UUID <039acfce-95e2-c8ca-ed5a-7fdba96d6f46>...
# Warn: Skipping UUID <8d5b3fb4-5967-2df2-b9d1-fb761f167d34>...
# Warn: Skipping UUID <267a3c0c-bbff-172f-4956-55e1ba8abace>...
# Warn: Skipping UUID <4c215bb5-b8af-750f-018b-e1237c21d549>...
# Warn: Skipping UUID <6f759472-0dc3-2415-67f2-46959b972c73>...
# Warn: Skipping UUID <1643fd00-cdf3-68a0-e221-ef7a457d8f03>...
# Warn: Skipping UUID <45df4e4b-fadd-652d-0acd-c3f2eeaef424>...
# Warn: Skipping UUID <3cf91524-85a9-03ea-a69b-edc1522e2fa0>...
# Warn: Skipping UUID <0b2947f7-48f6-0e3b-264b-b7c94a649c79>...
# Warn: Skipping UUID <24992b2d-20c5-a799-6e10-d4382ffef975>...
# Warn: Skipping UUID <37a89502-d3ed-df36-bf5b-89e548483cd8>...
# Warn: Skipping UUID <c0526597-47fe-102b-7877-79d1f2860277>...
# Warn: Skipping UUID <088df688-9ad4-c4b8-4162-68a0ce244967>...
# Warn: Skipping UUID <6174f4a9-a76e-8941-d9b0-08bfa996e31d>...
# Warn: Skipping UUID <31628ccc-cb55-c574-1da1-4ccb4354cf07>...
# Warn: Skipping UUID <bd705c81-b2cc-82db-f759-d03f221e2c7d>...
# Warn: Skipping UUID <3959bd0b-a18c-69b8-baff-8d937025061f>...
# Warn: Skipping UUID <6c971112-9e1a-cee6-b743-a43565cf54ab>...
# Warn: Skipping UUID <730d47e2-1d57-adbf-686b-4d8f34b24b99>...
# Warn: Skipping UUID <e7d35b0b-501c-5cdd-e351-904eba510dc7>...
# Warn: Skipping UUID <3d745551-19d5-a618-0ed0-0e5c9143f123>...
# Warn: Skipping UUID <af43d89b-cda4-29c6-6496-d9ec9559bcc4>...
# Warn: Skipping UUID <55e0a7f9-2ce0-3355-1194-5d8c9eaf8607>...
# Warn: Skipping UUID <d60980f9-1ba3-63e5-41d3-8962731eefae>...
# Warn: Skipping UUID <35db9adf-758b-b849-a5bf-101817d0ce14>...
# Warn: Skipping UUID <1edef5be-f094-2a45-f4de-79913ca61fcd>...
# Loading <./pkl/anomalies_aws_cloudtrail.pkl>...
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['pretaxcost'] = anomaly_dataset['pretaxcost']
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df[clm] = filter_df[clm].fillna('(none)')
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['pretaxcost'] = anomaly_dataset['pretaxcost']
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df[clm] = filter_df[clm].fillna('(none)')
# Executing SELECT * FROM cloudutilization WHERE servicename = 'AWS CloudTrail'...
# ('(none)', 'AWS                                               ')                     cloudprovidername  \
# usagedate
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
#
#                                                              cloudtype  \
# usagedate
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
#
#                      pretaxcost
# usagedate
# 2024-07-29 06:21:00       14.83
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.17
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.09
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00      154.69
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.01
# 2024-07-29 06:21:00        0.94
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.14
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.27
# 2024-07-29 06:21:00        0.02
# 2024-07-29 06:21:00        0.04
# 2024-07-29 06:21:00        0.00
# 2024-07-29 06:21:00        0.04
# 2024-07-29 06:21:00       10.79
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['pretaxcost'] = anomaly_dataset['pretaxcost']
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df[clm] = filter_df[clm].fillna('(none)')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Warn: Unable to predict <AWS CloudTrail - ('(none)', 'AWS                                               ')> due to insufficient data.
# Warn: Skipping UUID <3910ebe0-63eb-189e-396d-0fa8f547d5b4>...
# Warn: Skipping UUID <a1fbb87b-ed04-d57b-180f-eca44d5fe0c5>...
# Warn: Skipping UUID <39316b3c-2967-b961-5876-e1842ae7ce89>...
# Warn: Skipping UUID <7e4907d5-bf1f-9d36-b945-5500256a536f>...
# Warn: Skipping UUID <184c123d-7f70-a1c5-44b1-81a784a1f4b8>...
# Warn: Skipping UUID <53988246-e65c-27de-9db8-f507b6e5691f>...
# Warn: Skipping UUID <f3433e39-684c-109a-9dd7-e6641203871c>...
# Warn: Skipping UUID <22555296-eb4f-2be5-7940-608ad1646990>...
# Warn: Skipping UUID <d9481c1c-1db8-e177-6409-30ddaa288069>...
# Warn: Skipping UUID <babfb270-2a74-8d01-4ce4-e3f7a5fe35b3>...
# Warn: Skipping UUID <813bddee-0cc5-ba18-2c49-9ade055b5f68>...
# Warn: Skipping UUID <275be5cd-3652-9741-3b6f-58e10da82cff>...
# Warn: Skipping UUID <267e72a0-7c8f-489a-9915-bff8933b7c30>...
# Loading <./pkl/anomalies_amazon_elastic_compute_cloud.pkl>...
# Executing SELECT * FROM cloudutilization WHERE servicename = 'Amazon Elastic Compute Cloud'...
# ('(none)', 'AWS                                               ')                     cloudprovidername  \
# usagedate
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
#
#                                                              cloudtype  \
# usagedate
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
#
#                      pretaxcost
# usagedate
# 2024-07-29 06:21:00        2.53
# 2024-07-29 06:21:00       92.48
# 2024-07-29 06:21:00        2.69
# 2024-07-29 06:21:00      110.26
# 2024-07-29 06:21:00        2.03
# 2024-07-29 06:21:00       35.18
# 2024-07-29 06:21:00       36.73
# 2024-07-29 06:21:00       89.21
# 2024-07-29 06:21:00        0.42
# 2024-07-29 06:21:00       20.10
# 2024-07-29 06:21:00       60.51
# 2024-07-29 06:21:00        1.18
# 2024-07-29 06:21:00        5.89
# 2024-07-29 06:21:00      472.08
# 2024-07-29 06:21:00       30.93
# 2024-07-29 06:21:00       25.33
# 2024-07-29 06:21:00      456.34
# 2024-07-29 06:21:00        0.85
# 2024-07-29 06:21:00       29.03
# Warn: Unable to predict <Amazon Elastic Compute Cloud - ('(none)', 'AWS                                               ')> due to insufficient data.
# Warn: Skipping UUID <46e3ad29-e258-b2f2-1eb6-57638e1f425c>...
# Warn: Skipping UUID <26115ddd-e621-cf95-a5d8-40bb1ba7edb0>...
# Warn: Skipping UUID <77df4433-7dd8-fae2-10cb-92bffe9350cf>...
# Warn: Skipping UUID <4920f279-bc2c-5a90-ea03-efecaa42b6f4>...
# Warn: Skipping UUID <237d13cd-1a02-9754-4e46-3f9e5d0d3d66>...
# Warn: Skipping UUID <f59d51c4-5a3d-53c4-153e-49d215915d75>...
# Warn: Skipping UUID <2bceacdc-a1ce-f7c8-55e4-fc45c29b9f72>...
# Warn: Skipping UUID <a079bd06-0b2a-6eb6-f6d1-fb80ad02c8fc>...
# Warn: Skipping UUID <bf9e3a19-f303-cc35-9549-c6bdedf93d3d>...
# Warn: Skipping UUID <274ab54e-8391-b3a7-95c9-270ee552da58>...
# Warn: Skipping UUID <9e8d17f2-8b65-3fe8-4dd9-a4adef031728>...
# Warn: Skipping UUID <a463e2b6-5c3e-762d-8eb2-669029d6360d>...
# Warn: Skipping UUID <c624895f-d8d0-5c27-8122-528a6851b9fa>...
# Warn: Skipping UUID <0ebf68af-736e-e5f9-f061-9acaf3c45aa9>...
# Warn: Skipping UUID <020493a5-03b5-a909-9f74-3a63d5ddfcd2>...
# Warn: Skipping UUID <70c39854-d92a-9008-b8aa-17a40bddf9a8>...
# Warn: Skipping UUID <4486a4e5-5647-4fa7-791c-231964de4e6d>...
# Warn: Skipping UUID <15895a3c-7137-fd8a-7d72-206085744a65>...
# Warn: Skipping UUID <900b6a51-e6f2-a49c-8863-8462d5510f43>...
# Warn: Skipping UUID <0b10627f-f315-8785-d526-4cbec1fde313>...
# Warn: Skipping UUID <fd19c1ce-d307-40d2-a6eb-f921f3922bbb>...
# Warn: Skipping UUID <85d9b114-8884-9717-1da0-85d91416bd01>...
# Warn: Skipping UUID <f3a0fc59-b184-aacd-de65-a6a93ad6f399>...
# Warn: Skipping UUID <a6e9ab2f-c70c-d8b7-71cd-f5c80d88b6ae>...
# Warn: Skipping UUID <63d75ea9-967e-abdf-597f-19c61f4f175b>...
# Warn: Skipping UUID <68e28ccd-9bf3-998d-285c-345ebb114276>...
# Warn: Skipping UUID <4c529f3f-43c5-07f8-ec16-e3c098c698dd>...
# Warn: Skipping UUID <7284dc14-1b47-418d-57ab-55c073a99308>...
# Warn: Skipping UUID <7aea24d8-678e-c7b1-1581-092a997245b2>...
# Warn: Skipping UUID <63ffe9bb-5fb6-b6e0-0cfa-8a155875b682>...
# Warn: Skipping UUID <5174f249-60ea-d45b-b631-e2c719047efd>...
# Warn: Skipping UUID <068d5730-ecc9-d713-26b6-3b792dfedb64>...
# Warn: Skipping UUID <caf41c53-45c7-3965-0790-d6cc6337567d>...
# Warn: Skipping UUID <98dcc90d-9033-63ab-dfb3-977856c0f0dc>...
# Warn: Skipping UUID <e818d609-9336-37d9-ffdd-621944c48dc9>...
# Warn: Skipping UUID <ec3bcc21-ecb4-3e11-f626-b00137837526>...
# Warn: Skipping UUID <94869bd8-84b0-a299-d425-e34b7d6351aa>...
# Warn: Skipping UUID <67d16829-f284-0661-496b-160841c597a8>...
# Warn: Skipping UUID <ac2b356f-a3c2-2198-82eb-321cda6e3521>...
# Warn: Skipping UUID <a6a75b54-a91a-dada-141e-3f27df747452>...
# Warn: Skipping UUID <b5f40f65-3e88-cd00-c8fd-e091aa61e8c0>...
# Warn: Skipping UUID <fc4db19c-2399-12dc-6354-45bac88f6d27>...
# Warn: Skipping UUID <534ea622-3fdc-b378-e5bf-979a572b6634>...
# Warn: Skipping UUID <53f5c5c0-c575-9896-a3d8-5926e613d432>...
# Warn: Skipping UUID <2d744496-591f-1022-ceb4-0cdc870e48cd>...
# Warn: Skipping UUID <c4b6a6ea-bd73-a23c-9c67-149f1b0c3fe4>...
# Warn: Skipping UUID <406d341b-4211-8dd1-4385-c292e6fbffe8>...
# Warn: Skipping UUID <15edc261-eac4-2704-b93d-de2a552ac78d>...
# Warn: Skipping UUID <c2231331-f7f5-fda3-aa34-16ffd27e03f7>...
# Warn: Skipping UUID <69877055-12b4-a461-5a9e-0e80bccd6bd5>...
# Warn: Skipping UUID <7f2c84d4-8885-aa23-4c4d-b2c91060c7b8>...
# Loading <./pkl/anomalies_amazon_workspaces.pkl>...
# Model file not found. It might not be trained due to an insufficient data. Msg: [Errno 2] No such file or directory: './pkl/anomalies_amazon_workspaces.pkl'
# Warn: Skipping UUID <360f6c11-0328-da4e-2c3c-f741d17de81d>...
# Warn: Skipping UUID <d7e3216f-3ac3-0f7f-6682-fde33170701e>...
# Warn: Skipping UUID <16ec9a6b-d4bb-e27a-99e7-50ba4879e810>...
# Warn: Skipping UUID <7c85b555-6c20-10fa-30c6-4112afad9bba>...
# Warn: Skipping UUID <684fa1ed-5357-f0a0-5c90-219ceabdc51d>...
# Warn: Skipping UUID <de99e1ac-a5ff-cbea-32f9-6923690785b2>...
# Warn: Skipping UUID <64352aa2-5c62-01fa-ae0a-22d745b4f4a5>...
# Warn: Skipping UUID <f884ce86-59e9-bc02-c4bc-4a10632c7711>...
# Warn: Skipping UUID <6e469dbd-47c0-8ca2-23b9-708115b3b12a>...
# Warn: Skipping UUID <3f52f9e2-1064-adb0-e8c1-5df2365d96af>...
# Warn: Skipping UUID <505baef3-f7a8-399f-7181-6b5c56329cca>...
# Loading <./pkl/anomalies_storage.pkl>...
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['pretaxcost'] = anomaly_dataset['pretaxcost']
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df[clm] = filter_df[clm].fillna('(none)')
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['pretaxcost'] = anomaly_dataset['pretaxcost']
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df[clm] = filter_df[clm].fillna('(none)')
# Executing SELECT * FROM cloudutilization WHERE servicename = 'Storage'...
# ('(none)', 'Azure                                             ')            cloudprovidername  \
# usagedate
# 2024-03-01            (none)
# 2024-03-01            (none)
# 2024-03-01            (none)
# 2024-03-01            (none)
# 2024-03-01            (none)
# ...                      ...
# 2024-07-01            (none)
# 2024-07-01            (none)
# 2024-08-01            (none)
# 2024-07-01            (none)
# 2024-08-01            (none)
#
#                                                     cloudtype  pretaxcost
# usagedate
# 2024-03-01  Azure                                         ...        0.01
# 2024-03-01  Azure                                         ...       21.15
# 2024-03-01  Azure                                         ...        0.00
# 2024-03-01  Azure                                         ...        0.02
# 2024-03-01  Azure                                         ...        0.00
# ...                                                       ...         ...
# 2024-07-01  Azure                                         ...        0.17
# 2024-07-01  Azure                                         ...        0.00
# 2024-08-01  Azure                                         ...        0.02
# 2024-07-01  Azure                                         ...        0.02
# 2024-08-01  Azure                                         ...        0.00
#
# [74 rows x 3 columns]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 450ms/step
# Output of predicted next days:  14
# On Columns:  ['service_name', 'usage_date']
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df['usage_date'] = prediction_df['usage_date'].dt.date
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df['service_name'] = service_name
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df['created_on'] = now
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df['created_by'] = 'CRON/API'
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df[clm] = None if grp_name[i] == '(none)' else grp_name[i].strip()
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df[clm] = None if grp_name[i] == '(none)' else grp_name[i].strip()
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df.drop('last_original_days_value', axis=1, inplace=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_19880\477840163.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df.rename(columns={
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 170
#     163     prediction_df.rename(columns={
#     164         'cloudprovidername': 'cloud_provider_name',
#     165         'cloudtype': 'cloud_type',
#     166         'next_predicted_days_value': 'predicted_cost'
#     167     }, inplace=True)
#     169     # Save the prediction data into the database.
# --> 170     db.insert_or_update(tbl_name='alert_anomalies', df=prediction_df, on_columns=['service_name', 'usage_date'])
#     172     # Save the anomalies to the database.
#     173     #! db.insert_or_update(tbl_name='cloudalertmessagesdetails', df=anomaly_df, on_columns=['usage_date'])
#     175 if len(service_list) > 1:
#
# File Z:\works\datamatics\new\cloud\CloudCOEPredictionApp\app\db.py:126, in DB.insert_or_update(self, tbl_name, df, on_columns)
#     124         print(f'Error: Column: {clm} Msg: {str(e)}')
#     125         print(df[clm])
# --> 126     query += clm + " IN ('"+ "', '".join(values) +"')"
#     127 else:
#     128     query += clm + "='"+ df[clm][0] +"'"
#
# TypeError: sequence item 0: expected str instance, datetime.date found

# %%
prediction_df['usage_date']
# Out:
# datetime.date(2024, 9, 4)

# %%
if not isinstance(prediction_df['usage_date'][0], str):
    prediction_df['usage_date'] = prediction_df['usage_date'].astype(str)
    
values = prediction_df['usage_date'].values
values
# Out:
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_20812\2934614253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_df['usage_date'] = prediction_df['usage_date'].astype(str)
# array(['2024-08-31', '2024-09-01', '2024-09-02', '2024-09-03',
#        '2024-09-04', '2024-09-05', '2024-09-06', '2024-09-07',
#        '2024-09-08', '2024-09-09', '2024-09-10', '2024-09-11',
#        '2024-09-12', '2024-09-13'], dtype=object)

# %%
# anomaly_df[1] = True
anomaly_df
# Out:
# 2024-08-31 22:22:47.886710    False
# 2024-09-01 22:22:47.886710    False
# 2024-09-02 22:22:47.886710    False
# 2024-09-03 22:22:47.886710    False
# 2024-09-04 22:22:47.886710    False
# 2024-09-05 22:22:47.886710    False
# 2024-09-06 22:22:47.886710    False
# 2024-09-07 22:22:47.886710    False
# 2024-09-08 22:22:47.886710    False
# 2024-09-09 22:22:47.886710    False
# 2024-09-10 22:22:47.886710    False
# 2024-09-11 22:22:47.886710    False
# 2024-09-12 22:22:47.886710    False
# 2024-09-13 22:22:47.886710    False
# Freq: D, Name: next_predicted_days_value, dtype: bool

# %%
# anomaly_df.
# detected_anamolies = anomaly_df.loc[anomaly_df == True]
detected_anamolies
# Out:
# Series([], Freq: D, Name: next_predicted_days_value, dtype: bool)

# %%
anomaly_dataset[['cloudprovidername', 'cloudtype']]
# Out:
#                     cloudprovidername  \
# usagedate
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
# ...                               ...
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
# 2024-07-29 06:21:00              None
#
#                                                              cloudtype
# usagedate
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# ...                                                                ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
#
# [195 rows x 2 columns]

# %%
grp_name[1]
# Out:
# 'AWS                                               '

# %%
filter_columns = ['cloudprovidername', 'cloudtype']
filter_df = anomaly_dataset[filter_columns]
# Remove all None rows
for clm in filter_columns:
    filter_df[clm] = filter_df[clm].fillna('(none)')

for grp_name, df in filter_df.groupby(filter_columns):
    print(grp_name, df)

df



# prediction_df['service_name'] = service_name
# prediction_df['service_name'] = service_name
# prediction_df['service_name'] = service_name
# prediction_df
# Out:
# ('(none)', 'AWS                                               ')                     cloudprovidername  \
# usagedate
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# ...                               ...
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
#
#                                                              cloudtype
# usagedate
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# ...                                                                ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
#
# [195 rows x 2 columns]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_20812\3825133420.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df[clm] = filter_df[clm].fillna('(none)')
#                     cloudprovidername  \
# usagedate
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# ...                               ...
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
# 2024-07-29 06:21:00            (none)
#
#                                                              cloudtype
# usagedate
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# ...                                                                ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
# 2024-07-29 06:21:00  AWS                                           ...
#
# [195 rows x 2 columns]

# %%
import datetime as dt
import numpy as np

seasonal_data = pd.read_csv(r'./data/seasonal_data.csv')
months = ('jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec')


def fn(x):
    x = x.lower().split('-')
    return now.year, months.index(x[0])+1, int(x[1])
    
seasonal_data['StartDate'] = seasonal_data['StartDate'].apply(lambda x: dt.datetime(*fn(x)))
seasonal_data['EndDate'] = seasonal_data['EndDate'].apply(lambda x: dt.datetime(*fn(x)))
seasonal_data['MinThresholdValue'] = seasonal_data['MinThresholdValue'].astype(np.float64)
seasonal_data['MaxThresholdValue'] = seasonal_data['MaxThresholdValue'].astype(np.float64)

def get_latest_season_data(seasonal_data, within_days=1):
    # today = dt.date.today()
    today = dt.datetime.now()
    tomorrow = (today + dt.timedelta(days=within_days))
    latest_seasonal_data = seasonal_data.loc[
        (seasonal_data['StartDate'] >= now) & (seasonal_data['EndDate'] <= tomorrow)
    ]
    print(f'Date Range: {today} - {tomorrow}')
    return latest_seasonal_data
    
latest_seasonal_data = get_latest_season_data(seasonal_data, within_days=120)
if not latest_seasonal_data.empty:
    # Season time now.
    min_threshold_value = latest_seasonal_data['MinThresholdValue'].min()
    max_threshold_value = latest_seasonal_data['MaxThresholdValue'].max()
    print(f"Note: Ignore if usage cost is in-between '{min_threshold_value}' & '{max_threshold_value}'")

    # Find abnormal usage cost.
    prediction_df = prediction_df.loc[
        (prediction_df['predicted_cost'] < min_threshold_value) | (prediction_df['predicted_cost'] > max_threshold_value)
    ]

prediction_df
# anomaly_dataset
# Out:
# Date Range: 2024-08-30 22:22:48.035614 - 2024-12-28 22:22:48.035614
# Note: Ignore if usage cost is in-between '340.0' & '8000.0'
#     usage_date  predicted_cost       service_name cloud_provider_name  \
# 0   2024-08-31        1.019790  AWS Data Transfer                None
# 1   2024-09-01        1.615681  AWS Data Transfer                None
# 2   2024-09-02        2.301117  AWS Data Transfer                None
# 3   2024-09-03        3.170714  AWS Data Transfer                None
# 4   2024-09-04        4.358268  AWS Data Transfer                None
# 5   2024-09-05        6.007575  AWS Data Transfer                None
# 6   2024-09-06        8.440774  AWS Data Transfer                None
# 7   2024-09-07       12.189543  AWS Data Transfer                None
# 8   2024-09-08       15.663350  AWS Data Transfer                None
# 9   2024-09-09       16.929394  AWS Data Transfer                None
# 10  2024-09-10       16.292023  AWS Data Transfer                None
# 11  2024-09-11       14.686313  AWS Data Transfer                None
# 12  2024-09-12       12.922974  AWS Data Transfer                None
# 13  2024-09-13       11.538453  AWS Data Transfer                None
#
#    cloud_type
# 0         AWS
# 1         AWS
# 2         AWS
# 3         AWS
# 4         AWS
# 5         AWS
# 6         AWS
# 7         AWS
# 8         AWS
# 9         AWS
# 10        AWS
# 11        AWS
# 12        AWS
# 13        AWS

# %%
now.date()
# Out:
# datetime.date(2024, 8, 30)

# %%
# Disposition Prediction
model_name = 'disposition'
service_name = None


model_id = get_model_id(model_name, service_name)

# Load the saved model
pkl = get_saved_model(model_id) 
model = pkl['model']
label_encoders = pkl['encoders']

final_df = pd.DataFrame()
fetch_columns = ['appid', 'appname', 'appversion', 'age', 'businesscriticality', 'complexity', 'technologystack', 'focusarea']
required_columns=['appversion', 'age', 'businesscriticality', 'complexity', 'technologystack']
pred_table_columns = [
    'dispositionid', 'dispositionname', 'appname', 
    'focusarea', 'businesscriticality', 'technologystack', 
    # 'ballparkdevefforts', 'movegroup', 'rating'
]

for i, row in enumerate(db.fetch_data(tbl_name='applicationinventory', columns=fetch_columns)):
    # Convert into Dataframe
    df = pd.DataFrame([row], columns=fetch_columns)
    df.set_index('appid', inplace=True, drop=True)
    try:
        pred_df = predict_disposition(
            model, 
            label_encoders,
            df[required_columns]
        )['dispositionname']
        final_df = pd.concat([final_df, df.join(pred_df)])
    except Exception as e:
        print("Error:", row, e)

# Rename all "Column" name to lowercase.
final_df.columns = map(str.lower, final_df.columns)
print(final_df)
if not final_df.empty:
    # Remove unwanted columns from final prediction table.
    final_df.drop(['appversion', 'age', 'complexity'], axis=1, inplace=True)

# Insert into the database.
# db.insert_or_update_df(tbl_name='disposition', df=final_df)
on_columns = required_columns.copy()
on_columns.remove('complexity')
on_columns.remove('appversion')
on_columns.remove('age')
on_columns.append('appname')
db.insert_or_update(tbl_name='disposition', df=final_df, on_columns=on_columns)
# Out:
# Loading <./pkl/disposition.pkl>...
# Executing SELECT appid, appname, appversion, age, businesscriticality, complexity, technologystack, focusarea FROM applicationinventory ...
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = LabelEncoder().fit_transform(df[column])
# C:\install\works\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeyak\AppData\Local\Temp\ipykernel_12132\280383039.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dispositionname'] = label_encoders['disposition'].inverse_transform([y_pred])[0]
#                               appname appversion  age businesscriticality  \
# appid
# 61                             Apollo          1    2              Simple
# 62                             Apollo          1    1              Medium
# 63                           Artefact          1    3            Critical
# 64                           Artefact          1    4              Medium
# 65                       VisualEditor          1    7            Critical
# 66                       VisualEditor          1    5              Simple
# 67                       VisualEditor          1    2              Medium
# 68                       VisualEditor          1    1              Simple
# 69                       VisualEditor          1    3              Medium
# 70                       VisualEditor          1    7            Critical
# 71                       VisualEditor          1    5              Medium
# 72                 Data Visualisation          1    1              Medium
# 73                         LEDControl          1    6              Simple
# 74     Online Event Management System          1    9            Critical
# 75                     PaymentBilling          1   10            Critical
#
#       complexity technologystack      focusarea dispositionname
# appid
# 61        Simple            .Net   Runtime.0003        Re-write
# 62        Medium            .Net     Local.0014        Re-write
# 63       Complex            Java     Scale.0001        Re-write
# 64        Medium         Angular     Local.0006        Re-write
# 65       Complex           React     Local.0003        Re-write
# 66        Simple              c#     Local.0007        Re-write
# 67        Medium       Mainframe       COM.0001        Re-write
# 68        Simple             SAP     Local.0009        Re-write
# 69       Complex     Dynamic CRM     Local.0008        Re-write
# 70        Medium            Java     Local.0012        Re-write
# 71        Simple            .Net  Security.0001        Re-write
# 72        Medium           React     Scale.0001        Re-write
# 73        Simple       Mainframe   Runtime.0003        Re-write
# 74       Complex             SAP     Scale.0001        Re-write
# 75       Complex     Dynamic CRM     Scale.0001        Re-write
# On Columns:  ['businesscriticality', 'technologystack', 'appname']
# Error: Column: businesscriticality Msg: 0
# appid
# 61      Simple
# 62      Medium
# 63    Critical
# 64      Medium
# 65    Critical
# 66      Simple
# 67      Medium
# 68      Simple
# 69      Medium
# 70    Critical
# 71      Medium
# 72      Medium
# 73      Simple
# 74    Critical
# 75    Critical
# Name: businesscriticality, dtype: object
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 50
#      48 on_columns.remove('age')
#      49 on_columns.append('appname')
# ---> 50 db.insert_or_update(tbl_name='disposition', df=final_df, on_columns=on_columns)
#
# File Z:\works\datamatics\new\cloud\CloudCOEPredictionApp\app\db.py:127, in DB.insert_or_update(self, tbl_name, df, on_columns)
#     125         print(f'Error: Column: {clm} Msg: {str(e)}')
#     126         print(df[clm])
# --> 127     query += clm + " IN ('"+ "', '".join(values) +"')"
#     128 else:
#     129     query += clm + "='"+ df[clm][0] +"'"
#
# UnboundLocalError: cannot access local variable 'values' where it is not associated with a value

# %%
final_df['businesscriticality'].iloc[0]
# Out:
# 'Simple'
